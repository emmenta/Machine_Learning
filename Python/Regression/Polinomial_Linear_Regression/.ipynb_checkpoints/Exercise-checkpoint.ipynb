# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Create the table

# %%
data = {
    "conc" : [0.07,0.09,0.08,0.16,0.17,0.21,0.49,0.58,0.53,1.22,1.15,1.07,2.84,2.57,3.10],
    "time" : [9,9,9,7,7,7,5,5,5,3,3,3,1,1,1]
}
data = pd.DataFrame(data)
print(data)
# Out:
#     conc  time
# 0   0.07     9
# 1   0.09     9
# 2   0.08     9
# 3   0.16     7
# 4   0.17     7
# 5   0.21     7
# 6   0.49     5
# 7   0.58     5
# 8   0.53     5
# 9   1.22     3
# 10  1.15     3
# 11  1.07     3
# 12  2.84     1
# 13  2.57     1
# 14  3.10     1

# %%
x = data.iloc[:, 1].values
x = x.reshape(len(x), 1)
print(x)
# Out:
# [[9]
#  [9]
#  [9]
#  [7]
#  [7]
#  [7]
#  [5]
#  [5]
#  [5]
#  [3]
#  [3]
#  [3]
#  [1]
#  [1]
#  [1]]

# %%
y = data.iloc[:, :-1].values
print(y)
# Out:
# [[0.07]
#  [0.09]
#  [0.08]
#  [0.16]
#  [0.17]
#  [0.21]
#  [0.49]
#  [0.58]
#  [0.53]
#  [1.22]
#  [1.15]
#  [1.07]
#  [2.84]
#  [2.57]
#  [3.1 ]]

# %% [markdown]
# Plot the Linear Regression

# %%
from sklearn.linear_model import LinearRegression
slr = LinearRegression()
slr.fit(x, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x, y, color = 'blue')
plt.plot(x, slr.predict(x), color = 'red')
plt.title('Concenation vs Time')
plt.xlabel('time')
plt.ylabel('conc')
plt.show()

# %%
print(slr.predict([[3.5]]))
# Out:
# [[1.44133333]]

# %% [markdown]
# Do the Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poli = PolynomialFeatures(degree = 4)
x_poli = poli.fit_transform(x)
plr = LinearRegression()
plr.fit(x_poli, y)
# Out:
# LinearRegression()

# %% [markdown]
# Plot the Polynomial Regression

# %%
plt.scatter(x, y, color = 'blue')
plt.plot(x, plr.predict(x_poli), color = 'red')
plt.title('Concenation vs Time')
plt.xlabel('time')
plt.ylabel('conc')
plt.show()

# %%
x_grid = np.arange(min(x), max(x), 0.1)
x_grid = x_grid.reshape(len(x_grid), 1)
plt.scatter(x, y, color = 'blue')
plt.plot(x_grid, plr.predict(poli.fit_transform(x_grid)), color = 'red')
plt.title('Concenation vs Time')
plt.xlabel('time')
plt.ylabel('conc')
plt.show()
# Out:
# C:\Users\janne\AppData\Local\Temp\ipykernel_62556\2474771287.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid = np.arange(min(x), max(x), 0.1)

# %%
print(plr.predict(poli.fit_transform([[3.5]])))
# Out:
# [[0.93813965]]

# %%
print(plr.predict(poli.fit_transform([[1.2]])))
# Out:
# [[2.57920504]]
